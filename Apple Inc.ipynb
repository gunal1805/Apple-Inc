# %% [markdown]
# Problem statement:

# %% [markdown]
# The objective of this study is to perform exploratory data analysis on the AAPL (Apple Inc.) historical stock price dataset in order to understand its structural characteristics, statistical distribution, and overall data quality before conducting financial analysis or predictive modeling. The dataset includes key trading attributes such as date, opening price, closing price, highest and lowest prices, adjusted closing price, and trading volume. The analysis aims to examine the dataset’s dimensions, column structure, descriptive statistics, presence of missing values, duplicate records, and uniqueness of data entries to ensure reliability and suitability for further time series forecasting, trend analysis, and investment decision modeling.

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\HP\Documents\archive (4)\AAPL.csv")

# %% [markdown]
# Head:

# %%
print("\nFirst 5 rows:")
print(df.head())
# Out:
# First 5 rows:
#          Date      Open      High       Low     Close  Adj Close       Volume
# 0  1980-12-12  0.513393  0.515625  0.513393  0.513393   0.407747  117258400.0
# 1  1980-12-15  0.488839  0.488839  0.486607  0.486607   0.386473   43971200.0
# 2  1980-12-16  0.453125  0.453125  0.450893  0.450893   0.358108   26432000.0
# 3  1980-12-17  0.462054  0.464286  0.462054  0.462054   0.366972   21610400.0
# 4  1980-12-18  0.475446  0.477679  0.475446  0.475446   0.377609   18362400.0

# %% [markdown]
# Tail:

# %%
print("\nLast 5 rows:")
print(df.tail())
# Out:
# Last 5 rows:
#             Date        Open        High         Low       Close   Adj Close  \
# 9818  2019-11-19  267.899994  268.000000  265.390015  266.290009  266.290009
# 9819  2019-11-20  265.540009  266.079987  260.399994  263.190002  263.190002
# 9820  2019-11-21  263.690002  264.010010  261.179993  262.010010  262.010010
# 9821  2019-11-22  262.589996  263.179993  260.839996  261.779999  261.779999
# 9822  2019-11-25  262.709991  266.440002  262.519989  266.369995  266.369995
#
#           Volume
# 9818  19041800.0
# 9819  26558600.0
# 9820  30348800.0
# 9821  16331300.0
# 9822  21005100.0

# %% [markdown]
# Info:

# %%
print("\nInfo:")
print(df.info())
# Out:
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9823 entries, 0 to 9822
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       9823 non-null   object
#  1   Open       9822 non-null   float64
#  2   High       9822 non-null   float64
#  3   Low        9822 non-null   float64
#  4   Close      9822 non-null   float64
#  5   Adj Close  9822 non-null   float64
#  6   Volume     9822 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 537.3+ KB
# None

# %% [markdown]
# Describe:

# %%
print("\nStatistical Summary:")
print(df.describe())
# Out:
# Statistical Summary:
#               Open         High          Low        Close    Adj Close  \
# count  9822.000000  9822.000000  9822.000000  9822.000000  9822.000000
# mean     30.350057    30.640633    30.048298    30.352940    28.364033
# std      53.443016    53.908364    52.983661    53.464270    51.603590
# min       0.198661     0.198661     0.196429     0.196429     0.156008
# 25%       1.062500     1.085357     1.043571     1.066964     0.914089
# 50%       1.709286     1.742366     1.671429     1.712857     1.452872
# 75%      30.393928    30.555714    29.865358    30.233214    26.305946
# max     267.899994   268.000000   265.390015   267.100006   267.100006
#
#              Volume
# count  9.822000e+03
# mean   8.620720e+07
# std    8.623138e+07
# min    3.472000e+05
# 25%    3.318138e+07
# 50%    5.798940e+07
# 75%    1.076320e+08
# max    1.855410e+09

# %% [markdown]
# Missing Values:

# %%
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# Date         0
# Open         1
# High         1
# Low          1
# Close        1
# Adj Close    1
# Volume       1
# dtype: int64

# %% [markdown]
# Duplicates:

# %%
print("\nDuplicate Rows:")
print(df.duplicated().sum())
# Out:
# Duplicate Rows:
# 0

# %% [markdown]
# Unique Counts:

# %%
print("\nUnique Counts:")
print(df.nunique())
# Out:
# Unique Counts:
# Date         9823
# Open         5194
# High         5134
# Low          5110
# Close        5300
# Adj Close    6825
# Volume       9264
# dtype: int64

# %% [markdown]
# Columns:

# %%
print("\nColumns:")
print(df.columns)
# Out:
# Columns:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %% [markdown]
# Shape:

# %%
print("Shape:")
print(df.shape)
# Out:
# Shape:
# (9823, 7)

# %% [markdown]
# Full code and Output:

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\HP\Documents\archive (4)\AAPL.csv")

print("Shape:")
print(df.shape)

print("\nColumns:")
print(df.columns)

print("\nFirst 5 rows:")
print(df.head())

print("\nLast 5 rows:")
print(df.tail())

print("\nInfo:")
print(df.info())

print("\nStatistical Summary:")
print(df.describe())

print("\nMissing Values:")
print(df.isnull().sum())

print("\nDuplicate Rows:")
print(df.duplicated().sum())

print("\nUnique Counts:")
print(df.nunique())
# Out:
# Shape:
# (9823, 7)
#
# Columns:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')
#
# First 5 rows:
#          Date      Open      High       Low     Close  Adj Close       Volume
# 0  1980-12-12  0.513393  0.515625  0.513393  0.513393   0.407747  117258400.0
# 1  1980-12-15  0.488839  0.488839  0.486607  0.486607   0.386473   43971200.0
# 2  1980-12-16  0.453125  0.453125  0.450893  0.450893   0.358108   26432000.0
# 3  1980-12-17  0.462054  0.464286  0.462054  0.462054   0.366972   21610400.0
# 4  1980-12-18  0.475446  0.477679  0.475446  0.475446   0.377609   18362400.0
#
# Last 5 rows:
#             Date        Open        High         Low       Close   Adj Close  \
# 9818  2019-11-19  267.899994  268.000000  265.390015  266.290009  266.290009
# 9819  2019-11-20  265.540009  266.079987  260.399994  263.190002  263.190002
# 9820  2019-11-21  263.690002  264.010010  261.179993  262.010010  262.010010
# ...
