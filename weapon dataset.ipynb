# %% [markdown]
# Problem statement:

# %% [markdown]
# The objective of this project is to analyze the weapons dataset to identify patterns, classifications, and key characteristics of different types of weapons based on their attributes. The study aims to explore relationships between various features such as weapon type, origin, specifications, and other recorded parameters to detect trends, similarities, and potential anomalies. By performing exploratory data analysis and applying suitable machine learning techniques, the project seeks to develop insights that can support weapon categorization, prediction, or decision-making processes based on the given data.

# %%
import pandas as pd

# %% [markdown]
# To load the dataset:

# %%
df = pd.read_csv(r"C:\Users\HP\Documents\archive (1)\weapons_data.csv")

# %% [markdown]
# Shape:

# %%
print("Shape of dataset:")
print(df.shape)
# Out:
# Shape of dataset:
# (68, 5)

# %% [markdown]
# Column:

# %%
print("\nColumn names:")
print(df.columns)
# Out:
# Column names:
# Index(['Weapon Name', 'Ammo Count', 'Description', 'Tags', 'Type'], dtype='object')

# %% [markdown]
# Head:

# %%
print("\nFirst 5 rows:")
print(df.head())
# Out:
# First 5 rows:
#   Weapon Name  Ammo Count                                        Description  \
# 0       RGS50           3  The anti-materiel Launcher (AML) can lock on t...
# 1      MGL140           5  Grenade launcher with mid-sized magazine, low ...
# 2         M79           1      Deals area damage, requires skillful control.
# 3     GATLING        1200  Insane fire rate and power, but reduces mobility.
# 4         M60          68    Large magazines and solid mid-range fire power.
#
#                                 Tags            Type
# 0             HIGH DAMAGE, DESTROYER           Melee
# 1        AREA OF EFFECT, HIGH DAMAGE           Rifle
# 2         AREA OF EFFECT, PROJECTILE        Launcher
# 3  HIGH FIRE POWER, INSANE FIRE RATE  Marksman Rifle
# 4          MID RANGE, HIGH CLIP-SIZE      Projectile

# %% [markdown]
# Tail:

# %%
print("\nLast 5 rows:")
print(df.tail())
# Out:
# Last 5 rows:
#    Weapon Name  Ammo Count                                        Description  \
# 63         SVD          18  Very accurate automatic sniper rifle; only fou...
# 64         SKS          16   Semi-automatic sniper with pre-attached 4x scope
# 65         M14          24         Longest range, behaves like a sniper rifle
# 66  WOODPECKER          12   Uses AR ammo; great armor-piercing and precision
# 67        AC80           8  Two consecutive hits trigger bonus damage; ide...
#
#                                    Tags             Type
# 63                     RARE, LONG RANGE   Marksman Rifle
# 64              LONG RANGE, HIGH DAMAGE            Rifle
# 65              LONG RANGE, HIGH DAMAGE           Pistol
# 66  HIGH DAMAGE, HIGH ARMOR PENETRATION  Sub-machine gun
# 67        LONG RANGE, ADDITIONAL DAMAGE  Sub-machine gun

# %% [markdown]
# Info:

# %%
print("\nDataset Info:")
print(df.info())
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68 entries, 0 to 67
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Weapon Name  68 non-null     object
#  1   Ammo Count   68 non-null     int64
#  2   Description  68 non-null     object
#  3   Tags         68 non-null     object
#  4   Type         68 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.8+ KB
# None

# %% [markdown]
# Describe:

# %%
print("\nStatistical Summary:")
print(df.describe())
# Out:
# Statistical Summary:
#         Ammo Count
# count    68.000000
# mean     38.985294
# std     144.409709
# min       0.000000
# 25%       5.000000
# 50%      16.500000
# 75%      38.000000
# max    1200.000000

# %% [markdown]
# Isnull:

# %%
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# Weapon Name    0
# Ammo Count     0
# Description    0
# Tags           0
# Type           0
# dtype: int64

# %% [markdown]
# Full code:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv(r"C:\Users\HP\Documents\archive (1)\weapons_data.csv")

print("Shape of dataset:")
print(df.shape)

print("\nColumn names:")
print(df.columns)

print("\nFirst 5 rows:")
print(df.head())

print("\nLast 5 rows:")
print(df.tail())

print("\nDataset Info:")
print (df.info())

print("\nStatistical Summary:")
print(df.describe())

print("\nMissing Values:")
print(df.isnull().sum())
df = df.ffill()
print(df.isnull().sum())



print("\nDuplicate Rows:")
print(df.duplicated().sum())

print("\nUnique Value Count per Column:")
print(df.nunique())
# Out:
# Shape of dataset:
# (68, 5)
#
# Column names:
# Index(['Weapon Name', 'Ammo Count', 'Description', 'Tags', 'Type'], dtype='object')
#
# First 5 rows:
#   Weapon Name  Ammo Count                                        Description  \
# 0       RGS50           3  The anti-materiel Launcher (AML) can lock on t...
# 1      MGL140           5  Grenade launcher with mid-sized magazine, low ...
# 2         M79           1      Deals area damage, requires skillful control.
# 3     GATLING        1200  Insane fire rate and power, but reduces mobility.
# 4         M60          68    Large magazines and solid mid-range fire power.
#
#                                 Tags            Type
# 0             HIGH DAMAGE, DESTROYER           Melee
# 1        AREA OF EFFECT, HIGH DAMAGE           Rifle
# 2         AREA OF EFFECT, PROJECTILE        Launcher
# 3  HIGH FIRE POWER, INSANE FIRE RATE  Marksman Rifle
# 4          MID RANGE, HIGH CLIP-SIZE      Projectile
#
# Last 5 rows:
# ...
